# %% [markdown]
# # TITLE : INITIAL DATA EXPLORATION

# %% [markdown]
# Overview: This project analyzes the needs of Micosoft and the expansion of generating revenue with the creation of a movie studio. Descriptive analysis of movie studios across the world via gross income, movie rating, and budget would allow Microsoft to output its own studio with these factors.

# %% [markdown]
# Business Problem: We wanted to answer the probblem of starting a studio and where to begin. The three primary questions we wanted to focus on was
# How Important is Revenue to a studio.
# How Important is Rating to a studio.
# What is the most important thing.
# When starting out a studio there are a ton of variables to consider even beyond this analytical data that I present to you below. Please consider the below exploration when deciding to open up a studio

# %% [markdown]
# Data Understanding: The data utilized below comes from a private data sector in from the year 2019 across all sectors of movie studios. The data files will provide names of the studios, along with budgets and ratings of those movies in return the gross revenue is returned as well

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !ls
# Out:
# Movie Analysis Microsoft.ipynb
# Untitled.ipynb
# zippedData

# %%
# !ls zippedData/
# Out:
# bom.movie_gross.csv.gz
# imdb.name.basics.csv.gz
# imdb.title.akas.csv.gz
# imdb.title.basics.csv.gz
# imdb.title.crew.csv.gz
# imdb.title.principals.csv.gz
# imdb.title.ratings.csv.gz
# rt.movie_info.tsv.gz
# rt.reviews.tsv.gz
# tmdb.movies.csv.gz
# tn.movie_budgets.csv.gz
# untitled

# %%
revenue = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
revenue
#from the list below I was able to obain the sum of the studiios
#I was able to obtain the domestic gross of the top 15 movies.
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
domestic_revenue = high_domestic_gross['title'] #variable to locate movie titles
domestic_revenue

#easy to copy and paste
#StarWarsThe Force Awaken, Black Panther,Avengers: Infiity War, Jurassi World, Marvels The Avengers, Star Wars The Last Jedi 
#Incredibles 2 Rogue ONe: A StarWars Story,Beauty and the Beast, Finding Dory, Avengers: Age of Ultron,
#The Dark Knight Riss Th Hunger Games: Catching Fire Jurrassic World Fallen Kingdom Toy story 3
# Out:
# 1872       Star Wars: The Force Awakens
# 3080                      Black Panther
# 3079             Avengers: Infinity War
# 1873                     Jurassic World
# 727               Marvel's The Avengers
# 2758           Star Wars: The Last Jedi
# 3082                      Incredibles 2
# 2323       Rogue One: A Star Wars Story
# 2759        Beauty and the Beast (2017)
# 2324                       Finding Dory
# 1875            Avengers: Age of Ultron
# 729               The Dark Knight Rises
# 1131    The Hunger Games: Catching Fire
# 3081     Jurassic World: Fallen Kingdom
# 0                           Toy Story 3
# Name: title, dtype: object

# %%
#Wanted to display the top grossing movies of all time

high_domestic_gross = revenue.sort_values('domestic_gross', ascending = False).head(15)
domestic_gross = high_domestic_gross['domestic_gross'].head(15) #My Plot Point

domestic_gross



#StarWarsThe Force Awaken, Black Panther,Avengers: Infiity War, Jurassi World, Marvels The Avengers, Star Wars The Last Jedi 
#Incredibles 2 Rogue ONe: A StarWars Story,Beauty and the Beast, Finding Dory, Avengers: Age of Ultron,
#The Dark Knight Riss Th Hunger Games: Catching Fire Jurrassic World Fallen Kingdom Toy story 3
# Out:
# 1872    936700000.0
# 3080    700100000.0
# 3079    678800000.0
# 1873    652300000.0
# 727     623400000.0
# 2758    620200000.0
# 3082    608600000.0
# 2323    532200000.0
# 2759    504000000.0
# 2324    486300000.0
# 1875    459000000.0
# 729     448100000.0
# 1131    424700000.0
# 3081    417700000.0
# 0       415000000.0
# Name: domestic_gross, dtype: float64

# %%
the_movies = ['StarWarsThe Force Awaken' , 'Black Panther' ,' Avengers: Infiity War', 'Jurassi World' , 'Marvels The Avengers' , 'Star Wars The Last Jedi' , 
'Incredibles 2' ,  'Rogue One: A StarWars Story', 'Beauty and the Beast' , 'Finding Dory' , 'Avengers: Age of Ultron' ,
'The Dark Knight Rises' ,  'The Hunger Games: Catching Fire', 'Jurrassic World Fallen Kingdom' , 'Toy story 3']
domestic_gross
sns.set()
plt.xlabel('Top Grossing Movies Ever', size = 'large' )
plt.ylabel('Gross Revenue, MIL')
plt.title('MONEY MONEY MONEY')
plt.xlim(0,25)
cl = ['purple', 'yellow', 'green', 'pink', 'grey', 'blue', 'red', 'orange', 'black']
plt.xticks(color = 'purple', size = 'large')
plt.bar(the_movies, domestic_gross, width=1.0, color = cl)
plt.rcParams['figure.figsize'] = [15,15]
plt.xticks(rotation = 90)
plt.show()

# %%
budget = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %%
budget
 #The only file with production budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
productionbudge = production_price.loc[production_price ['movie'].isin(domestic_revenue)].head(15) 
productionbudge

#As you can see this is the only file in which has production budget in which 
#I wanted to compare and contrast the production budget to domestic gross

# %%
the_movies = ['StarWarsThe Force Awaken' , 'Black Panther' ,' Avengers: Infiity War', 'Jurassi World' , 'Marvels The Avengers' , 'Star Wars The Last Jedi' , 
'Incredibles 2' ,  'Rogue One: A StarWars Story', 'Beauty and the Beast' , 'Finding Dory' , 'Avengers: Age of Ultron' ,
'The Dark Knight Rises' ,  'The Hunger Games: Catching Fire', 'Jurrassic World Fallen Kingdom' , 'Toy story 3']
production_budget1 = [245000000, 200000000 ,300000000 , 215000000, 300000000 , 200000000, 200000000 ,330600000 , 25000000, 200000000,330600000, 275000000, 130000000, 170000000, 200000000]
sns.set()
plt.xlabel('Top Grossing Movies Ever', size = 'large' )
plt.ylabel('Production Cost, MIL')
plt.title('Lights, Camera, Action')
plt.xlim(0,25)
cl = ['blue', 'orange', 'yellow', 'black', 'pink', 'purple', 'green', 'grey', 'brown']
plt.xticks(color = 'purple', size = 'large')
plt.bar(the_movies, production_budget1, width=1.0, color = cl)
plt.rcParams['figure.figsize'] = [15,15]
plt.xticks(rotation = 90)
plt.show()

# %%
basics = pd.read_csv('zippedData/tmdb.movies.csv.gz')
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 7               7      [16, 10751, 35]   10193                en
# 3444         3444             [28, 16]   86841                en
# 5182         5182     [28, 80, 18, 53]   49026                en
# 7893         7893        [12, 28, 878]  101299                en
# 14169       14169        [28, 12, 878]   99861                en
# 14172       14172    [28, 12, 878, 14]  140607                en
# 14193       14193    [28, 12, 878, 53]  135397                en
# 17385       17385    [28, 12, 878, 14]  140607                en
# 17401       17401        [28, 12, 878]  330459                en
# 17454       17454  [12, 16, 35, 10751]  127380                en
# 20624       20624    [14, 12, 878, 28]  181808                en
# 20655       20655        [28, 12, 878]  330459                en
# 23811       23811         [12, 28, 14]  299536                en
# 23817       23817    [28, 12, 14, 878]  284054                en
# 23826       23826  [28, 12, 16, 10751]  260513                en
# 23829       23829        [28, 12, 878]  351286                en
# 23831       23831    [14, 12, 878, 28]  181808                en
#
#                         original_title  popularity release_date  \
# 7                          Toy Story 3      24.445   2010-06-17
# 3444                     Black Panther       2.058   2011-01-18
# 5182             The Dark Knight Rises      26.220   2012-07-20
# 7893   The Hunger Games: Catching Fire      20.187   2013-11-22
# 14169          Avengers: Age of Ultron      44.383   2015-05-01
# 14172     Star Wars: The Force Awakens      32.281   2015-12-18
# 14193                   Jurassic World      20.709   2015-06-12
# 17385     Star Wars: The Force Awakens      32.281   2015-12-18
# 17401     Rogue One: A Star Wars Story      21.401   2016-12-16
# 17454                     Finding Dory      15.393   2016-06-17
# 20624         Star Wars: The Last Jedi      34.293   2017-12-15
# 20655     Rogue One: A Star Wars Story      21.401   2016-12-16
# 23811           Avengers: Infinity War      80.773   2018-04-27
# 23817                    Black Panther      44.140   2018-02-16
# 23826                    Incredibles 2      36.286   2018-06-15
# 23829   Jurassic World: Fallen Kingdom      34.958   2018-06-22
# 23831         Star Wars: The Last Jedi      34.293   2017-12-15
#
#                                  title  vote_average  vote_count
# 7                          Toy Story 3           7.7        8340
# 3444                     Black Panther           5.1          11
# 5182             The Dark Knight Rises           7.7       13933
# 7893   The Hunger Games: Catching Fire           7.4       11170
# 14169          Avengers: Age of Ultron           7.3       13457
# 14172     Star Wars: The Force Awakens           7.4       12641
# 14193                   Jurassic World           6.6       14056
# 17385     Star Wars: The Force Awakens           7.4       12641
# 17401     Rogue One: A Star Wars Story           7.5        9296
# 17454                     Finding Dory           7.0        7845
# 20624         Star Wars: The Last Jedi           7.0        8534
# 20655     Rogue One: A Star Wars Story           7.5        9296
# 23811           Avengers: Infinity War           8.3       13948
# 23817                    Black Panther           7.4       12365
# 23826                    Incredibles 2           7.6        6354
# 23829   Jurassic World: Fallen Kingdom           6.5        5995
# 23831         Star Wars: The Last Jedi           7.0        8534

# %%
basics.loc[basics.title.isin (domestic_revenue)].mean()
#Primary focus on he vote_average these are the top 15 grossing moies of all time and the voting average is 7.2
# Out:
# Unnamed: 0       15981.941176
# id              183007.882353
# popularity          30.911882
# vote_average         7.200000
# vote_count        9906.823529
# dtype: float64

# %%
ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
ratings
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
ratings['averagerating'].mean()

#The Average for a vote across the board is a 6.3 no matter what your production value is.
# Out:
# 6.332728552859568

# %%
team = pd.read_csv('zippedData/imdb.name.basics.csv.gz')

# %%
team
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
#                                known_for_titles
# 0       tt0837562,tt2398241,tt0844471,tt0118553
# 1       tt0896534,tt6791238,tt0287072,tt1682940
# 2       tt1470654,tt0363631,tt0104030,tt0102898
# 3       tt0114371,tt2004304,tt1618448,tt1224387
# 4       tt0452644,tt0452692,tt3458030,tt2178256
# ...                                         ...
# 606643                                      NaN
# 606644                      tt9090932,tt8737130
# 606645                      tt8734436,tt9615610
# 606646                                      NaN
# 606647                                tt8743182
#
# [606648 rows x 6 columns]

# %%
revenue
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
how_much = revenue.groupby(['studio', 'domestic_gross']).sum()
how_much.sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-f8d4f1c3f3f1> in <module>
#       1 how_much = revenue.groupby(['studio', 'domestic_gross']).sum()
# ----> 2 how_much.sort_values(ascending = False)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
studio_count = revenue.groupby(['studio'])['title'].count()
studio_count.sort_values(ascending = False).head(15)
# Out:
# studio
# IFC       166
# Uni.      147
# WB        140
# Fox       136
# Magn.     136
# SPC       123
# Sony      110
# BV        106
# LGF       103
# Par.      101
# Eros       89
# Wein.      77
# CL         74
# Strand     68
# FoxS       67
# Name: title, dtype: int64
